# %%
from nltk.sentiment import SentimentIntensityAnalyzer
import nltk
nltk.download('vader_lexicon')

# %%
import random
gens = ['Alexandre L', 'Alexandre J', 'Bastien', 'Elise', 'Elliot', 'Laure', 'Lea', 'Melanie', 'Sami', 'Sara', 'Cyril']
gens2 = ['Alexandre L', 'Alexandre J', 'Bastien', 'Elise', 'Elliot', 'Laure', 'Lea', 'Melanie', 'Sami', 'Sara', 'Cyril']
random.shuffle(gens2)
cadeau = [{gens[k]:gens2[k]}for k in range(len(gens))]
cadeau
# Out:
# [{'Alexandre L': 'Laure'},
#  {'Alexandre J': 'Bastien'},
#  {'Bastien': 'Alexandre J'},
#  {'Elise': 'Elliot'},
#  {'Elliot': 'Elise'},
#  {'Laure': 'Cyril'},
#  {'Lea': 'Sara'},
#  {'Melanie': 'Sami'},
#  {'Sami': 'Melanie'},
#  {'Sara': 'Alexandre L'},
#  {'Cyril': 'Lea'}]

# %%
sia = SentimentIntensityAnalyzer()
sentiment = sia.polarity_scores("Once more, you open the door")
print(sentiment)
# Out:
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
